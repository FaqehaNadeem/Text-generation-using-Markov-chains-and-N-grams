# %%
import nltk
nltk.download('reuters')
#from nltk.corpus import reuters
nltk.download('punkt')
import nltk
from nltk import word_tokenize
from nltk.util import ngrams
from collections import Counter
from nltk.corpus import reuters
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package reuters to /home/faqeha/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt to /home/faqeha/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import matplotlib.pyplot as plt

# %%
 nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
words =nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')

# %%
print(len(words))
# Out:
# 37360

# %%
unigrams = ngrams(words,1)

# %%
print(Counter(unigrams))
# Out:
# Counter({(',',): 2892, ('.',): 1886, ('the',): 860, ("'",): 729, ('and',): 606, ('of',): 576, ('to',): 576, (':',): 565, ('I',): 553, ('you',): 479, ('?',): 459, ('a',): 449, ('my',): 435, ('in',): 359, ('it',): 354, ('Ham',): 337, ('is',): 304, (';',): 298, ('not',): 286, ('his',): 266, ('And',): 257, ('that',): 257, ('your',): 233, ('this',): 232, ('me',): 227, ('d',): 223, ('with',): 212, ('Lord',): 211, ('him',): 178, ('be',): 176, ('King',): 172, ('for',): 169, ('haue',): 161, ('he',): 160, ('but',): 146, ('so',): 145, ('as',): 142, ('The',): 133, ('will',): 131, ('on',): 123, ('s',): 122, ('That',): 120, ('our',): 118, ('-',): 117, ('what',): 116, ('are',): 113, ('To',): 109, ('shall',): 104, ('But',): 103, ('Hamlet',): 99, ('we',): 98, ('Hor',): 95, ('What',): 95, ('all',): 95, ('thou',): 93, ('by',): 91, ('no',): 91, ('her',): 90, ('t',): 89, ('do',): 84, ('more',): 83, ('thy',): 83, ('Enter',): 82, ('from',): 80, ('was',): 77, ('For',): 76, ('good',): 76, ('Oh',): 76, ('then
# ...

# %%
 nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
words2 = nltk.corpus.gutenberg.words('austen-persuasion.txt')

# %%
print(len(words2))
# Out:
# 98171

# %%
unigrams2 = ngrams(words2,1)

# %%
print(Counter(unigrams2))
# Out:
# Counter({(',',): 6750, ('the',): 3120, ('to',): 2775, ('.',): 2741, ('and',): 2739, ('of',): 2564, ('a',): 1529, ('in',): 1346, ('was',): 1330, (';',): 1290, ('had',): 1177, ('her',): 1159, ('I',): 1124, ('be',): 949, ('not',): 926, ('it',): 857, ('that',): 853, ('she',): 819, ('"',): 793, ('as',): 787, ('he',): 736, ('for',): 695, ('with',): 643, ('his',): 625, ('have',): 583, ('but',): 553, ('you',): 548, ("'",): 525, ('at',): 519, ('all',): 517, ('Anne',): 497, ('been',): 496, ('s',): 485, ('him',): 467, ('could',): 444, ('were',): 426, ('very',): 425, ('which',): 415, ('by',): 411, ('is',): 393, ('on',): 386, ('."',): 369, ('would',): 351, ('so',): 338, ('She',): 327, ('they',): 323, ('no',): 309, ('-',): 308, ('Captain',): 297, ('Mrs',): 291, ('from',): 290, ('Elliot',): 288, ('or',): 274, ('their',): 273, ('them',): 270, ('more',): 269, ('Mr',): 256, ('!',): 253, ('than',): 243, ('an',): 238, ('must',): 228, ('He',): 225, ('one',): 221, ('being',): 220, ('Wentworth',): 218, ('t
# ...

# %%
fd = nltk.FreqDist(words)
plt.figure(figsize=(15,12))
fd.plot(30,cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
fd = nltk.FreqDist(words2)
plt.figure(figsize=(15,12))
fd.plot(30,cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
bigrams_corpus_1 = ngrams(words,2)

# %%
print(Counter(bigrams_corpus_1))
# Out:
# Counter({('Ham', '.'): 337, (',', 'and'): 305, ("'", 'd'): 223, (',', 'And'): 161, ('.', 'I'): 151, ('my', 'Lord'): 146, ("'", 's'): 122, (',', 'I'): 105, ('King', '.'): 96, ('Hor', '.'): 95, ("'", 't'): 84, ('.', 'Enter'): 73, (',', 'That'): 73, ('Lord', ','): 73, ('.', 'What'): 67, ('in', 'the'): 65, (',', 'that'): 63, ('?', 'Ham'): 62, ('Qu', '.'): 62, ('Laer', '.'): 60, ('of', 'the'): 59, (',', 'my'): 57, ('to', 'the'): 56, ('Ophe', '.'): 56, ('I', 'haue'): 53, ('th', "'"): 52, ('Pol', '.'): 49, ('.', 'Oh'): 49, (',', 'the'): 48, ('.', 'My'): 46, (',', 'to'): 45, (',', 'The'): 45, (',', 'but'): 45, ('Lord', 'Ham'): 44, ('I', 'am'): 43, (',', 'or'): 43, ('.', 'The'): 43, ('Rosin', '.'): 43, ('.', 'But'): 42, ('d', ','): 39, ("'", 'tis'): 38, ('.', 'How'): 38, (',', 'As'): 38, ('Polon', '.'): 38, (',', 'as'): 36, (',', 'you'): 35, ('.', 'Why'): 35, ('I', 'will'): 35, (',', 'To'): 34, ('the', 'King'): 33, ('.', 'It'): 33, ('Lord', '?'): 33, ('Mar', '.'): 31, ('it', ','): 31, ('?', '
# ...

# %%
cc = Counter(bigrams_corpus_1)

# %%
bigrams_corpus_2 = ngrams(words2,2)

# %%
print(Counter(bigrams_corpus_2))
# Out:
# Counter({(',', 'and'): 1263, ("'", 's'): 485, (';', 'and'): 472, ('of', 'the'): 425, ('to', 'be'): 371, ('in', 'the'): 312, ('.', 'She'): 283, ('had', 'been'): 254, ('.', 'I'): 241, (';', 'but'): 233, (',', 'I'): 211, (',', 'but'): 199, ('.', '"'): 198, ('.', 'He'): 198, ('Captain', 'Wentworth'): 196, (',', 'that'): 195, ('."', '"'): 195, (',', 'she'): 184, (',', 'as'): 177, (',', 'in'): 175, ('to', 'the'): 174, ('Mr', 'Elliot'): 174, ('.', 'The'): 166, (',', '"'): 165, (',', 'to'): 160, ('she', 'had'): 147, ('Lady', 'Russell'): 147, ('could', 'not'): 147, ('.', 'It'): 144, ('he', 'had'): 137, (',', 'which'): 137, (',', 'the'): 134, ('it', 'was'): 132, ('Sir', 'Walter'): 131, ('of', 'her'): 129, (',', 'or'): 125, ('I', 'have'): 125, ('I', 'am'): 123, ('all', 'the'): 122, ('have', 'been'): 117, ('"', 'I'): 114, ('she', 'was'): 113, ('of', 'his'): 112, ('and', 'the'): 109, (',', 'he'): 107, ('for', 'the'): 107, ('Anne', ','): 101, (',', 'with'): 100, ('.', 'They'): 97, (',', 'was'): 95
# ...

# %%
fdist = nltk.FreqDist(bigrams_corpus_1)
